# %%
import pandas as pd

# %%
dict1={"car":["hndi","bmw","civic","suzuki","lbm","mno"],
      "prices":[848,00000,10000000,7800000,540000,87853485482]}

# %%
auto=pd.DataFrame(dict1)

# %%
auto
# Out:
#       car       prices
# 0    hndi          848
# 1     bmw            0
# 2   civic     10000000
# 3  suzuki      7800000
# 4     lbm       540000
# 5     mno  87853485482

# %% [markdown]
# # import titianic data set

# %%
data=pd.read_csv("tested.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
data.shape
# Out:
# (418, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# to analyze distinct value in each columns we can find value _counts method

# %%
data["Embarked"].value_counts()
# Out:
# Embarked
# S    270
# C    102
# Q     46
# Name: count, dtype: int64

# %%
data["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# # ACCESSING DATA SET

# %%
data["Name"]
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
data[["Name","Sex","Survived"]]
# Out:
#                                              Name     Sex  Survived
# 0                                Kelly, Mr. James    male         0
# 1                Wilkes, Mrs. James (Ellen Needs)  female         1
# 2                       Myles, Mr. Thomas Francis    male         0
# 3                                Wirz, Mr. Albert    male         0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female         1
# ..                                            ...     ...       ...
# 413                            Spector, Mr. Woolf    male         0
# 414                  Oliva y Ocana, Dona. Fermina  female         1
# 415                  Saether, Mr. Simon Sivertsen    male         0
# 416                           Ware, Mr. Frederick    male         0
# 417                      Peter, Master. Michael J    male         0
#
# [418 rows x 3 columns]

# %%
pd.set_option('display.max_rows', None)  # Set the maximum number of rows to display

# Now display your DataFrame
print(data)

# To reset the options to the default values
pd.reset_option('display.max_rows')
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# 5            897         0       3
# 6            898         1       3
# 7            899         0       2
# 8            900         1       3
# 9            901         0       3
# 10           902         0       3
# 11           903         0       1
# 12           904         1       1
# 13           905         0       2
# 14           906         1       1
# 15           907         1       2
# 16           908         0       2
# 17           909         0       3
# 18           910         1       3
# 19           911         1       3
# 20           912         0       1
# 21           913         0       3
# 22           914         1       1
# 23           915         0       1
# 24           916         1       1
# ...

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
data.iloc[0,:].values# accessing indivitual value
# Out:
# array([892, 0, 3, 'Kelly, Mr. James', 'male', 34.5, 0, 0, '330911',
#        7.8292, nan, 'Q'], dtype=object)

# %%
data.iloc[0,:]
# Out:
# PassengerId                 892
# Survived                      0
# Pclass                        3
# Name           Kelly, Mr. James
# Sex                        male
# Age                        34.5
# SibSp                         0
# Parch                         0
# Ticket                   330911
# Fare                     7.8292
# Cabin                       NaN
# Embarked                      Q
# Name: 0, dtype: object

# %%
data.iloc[0,:3]#iloc does not support name of columns
# Out:
# PassengerId    892
# Survived         0
# Pclass           3
# Name: 0, dtype: object

# %%
data.loc[2:6,["Pclass","Name"]]
# Out:
#    Pclass                                          Name
# 2       2                     Myles, Mr. Thomas Francis
# 3       3                              Wirz, Mr. Albert
# 4       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5       3                    Svensson, Mr. Johan Cervin
# 6       3                          Connolly, Miss. Kate

# %%
new_data=data["Sex"]=="male"

# %%
new_data
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 413     True
# 414    False
# 415     True
# 416     True
# 417     True
# Name: Sex, Length: 418, dtype: bool

# %%
new_data.count()
# Out:
# 418

# %%
data.shape
# Out:
# (418, 12)

# %% [markdown]
# # SORTING OF DATA

# %%
data.sort_values("Fare")
# Out:
#      PassengerId  Survived  Pclass  \
# 266         1158         0       1
# 372         1264         0       1
# 21           913         0       3
# 133         1025         0       3
# 116         1008         0       3
# ..           ...       ...     ...
# 59           951         1       1
# 53           945         1       1
# 69           961         1       1
# 343         1235         1       1
# 152         1044         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 266              Chisholm, Mr. Roderick Robert Crispin    male   NaN      0
# 372                            Ismay, Mr. Joseph Bruce    male  49.0      0
# 21                           Olsen, Master. Artur Karl    male   9.0      0
# 133                              Thomas, Mr. Charles P    male   NaN      1
# 116                                   Thomas, Mr. John    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # grouping and aggregation

# %%
groups=data.groupby(["Sex"])

# %%
groups

# %%
groups.sum()
# Out:
#         PassengerId  Survived  Pclass  \
# Sex
# female       166712       152     326
# male         293297         0     621
#
#                                                      Name      Age  SibSp  \
# Sex
# female  Wilkes, Mrs. James (Ellen Needs)Hirvonen, Mrs....  3844.59     86
# male    Kelly, Mr. JamesMyles, Mr. Thomas FrancisWirz,...  6205.91    101
#
#         Parch                                             Ticket       Fare  \
# Sex
# female     91  3632723101298330972265721228W.E.P. 5734SC/PARI...  7561.6502
# male       73  3309112402763151547538248738A/4 48871349220694...  7294.8874
#
#                                                     Cabin  \
# Sex
# female  B45E31B57 B59 B63 B66B36D19D15C23 C25 C27B61C2...
# male    A21C78D34A9C31F G63B57 B59 B63 B66C53D43C132C5...
#
#                                                  Embarked
# Sex
# female  SSQCSSCSCSCCSSSSSSCSSSCQSQSQSCSQQSQSSSSCCQCQSS...
# male    QQSSSSSSSQCCSCSCSCSSCCSSCSSSCQSCCQSSSSSSCSCSCC...

# %%
data["Survived"].sum()
# Out:
# 152

# %%
groups.size()
# Out:
# Sex
# female    152
# male      266
# dtype: int64

# %%
groups.count()
# Out:
#         PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# female          152       152     152   152  127    152    152     152   152
# male            266       266     266   266  205    266    266     266   265
#
#         Cabin  Embarked
# Sex
# female     44       152
# male       47       266
